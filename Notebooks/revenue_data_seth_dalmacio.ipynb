# %%
import pandas as pd
import numpy as np

revenue_data = pd.read_csv("/Users/ylsstudent/Documents/Data_Analytics_Bootcamp/Projects/BootcampProject3/nfl_project/Resources/revenue_data.csv")

revenue_data.head()
# Out:
#                    Team Revenue (in Millions)
# 0        Dallas Cowboys                 1,200
# 1     Las Vegas Raiders                   779
# 2      Los Angeles Rams                   756
# 3  New England Patriots                   712
# 4       New York Giants                   691

# %%
file_path = "/Users/ylsstudent/Documents/Data_Analytics_Bootcamp/Projects/BootcampProject3/nfl_project/Cleaned_Data/clean_team_data.csv"
team_data = pd.read_csv(file_path)
team_data.head()
# Out:
#            team_name  team_id  stadium_id  city_id
# 0  Arizona Cardinals        1         101      201
# 1    Atlanta Falcons        2         102      202
# 2   Baltimore Ravens        3         103      203
# 3      Buffalo Bills        4         104      204
# 4  Carolina Panthers        5         105      205

# %%
revenue_data["Revenue (in Millions)"] = revenue_data["Revenue (in Millions)"].str.replace(",", "", regex=False).astype(int)
revenue_data.head()
# Out:
#                    Team  Revenue (in Millions)
# 0        Dallas Cowboys                   1200
# 1     Las Vegas Raiders                    779
# 2      Los Angeles Rams                    756
# 3  New England Patriots                    712
# 4       New York Giants                    691

# %%
revenue_data = revenue_data.rename(columns = {"Team": "team_name"})
revenue_data.head()
# Out:
#               team_name  Revenue (in Millions)
# 0        Dallas Cowboys                   1200
# 1     Las Vegas Raiders                    779
# 2      Los Angeles Rams                    756
# 3  New England Patriots                    712
# 4       New York Giants                    691

# %%
revenue_data = revenue_data.rename(columns = {"Revenue (in Millions)": "2023_revenue(millions)"})
revenue_data.head()
# Out:
#               team_name  2023_revenue(millions)
# 0        Dallas Cowboys                    1200
# 1     Las Vegas Raiders                     779
# 2      Los Angeles Rams                     756
# 3  New England Patriots                     712
# 4       New York Giants                     691

# %%
merged_data = pd.merge(revenue_data, team_data, on = "team_name")
merged_data.head()
# Out:
#               team_name  2023_revenue(millions)  team_id  stadium_id  city_id
# 0        Dallas Cowboys                    1200        9         109      209
# 1     Las Vegas Raiders                     779       17         117      217
# 2      Los Angeles Rams                     756       19         118      218
# 3  New England Patriots                     712       22         121      221
# 4       New York Giants                     691       24         123      223

# %%
revenue_data_cleaned = merged_data.drop(columns = ["team_name", "city_id", "stadium_id"])

# %%
revenue_data_cleaned = revenue_data_cleaned[['team_id', 'Revenue (in Millions)']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 revenue_data_cleaned = revenue_data_cleaned[['team_id', 'Revenue (in Millions)']]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
# ...
